# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype'] = 'none'

# %%
import pandas as pd
df = pd.read_csv(r'D:\soil\manuscript\draft\mine\nanopore.csv')
df
# Out:
#      Sample   Total GB  N50 length  Mean Q       Site
# 0   CPSNJ01  45.386270       12017    15.8  NanJing_8
# 1   CPSNJ02  57.192759       15910    15.7  NanJing_8
# 2   CPSNJ03  46.479399       16752    16.0  NanJing_8
# 3   CPSNJ04  71.459105       17489    16.1  NanJing_8
# 4   CPSNJ08  48.708406       10742    15.0  NanJing_8
# 5   CPSNJ09  67.587256       17853    15.7  NanJing_8
# 6   CPSNJ10  59.134384       18330    15.7  NanJing_8
# 7   CPSNJ11  54.003232       19505    15.7  NanJing_8
# 8   CPSNJ13  47.460343       19467    15.9  NanJing_8
# 9   CPSNJ14  54.746032       19967    15.9  NanJing_8
# 10  CPSNJ15  58.001958       16509    15.6  NanJing_8
# 11  CPSNJ16  39.962099       19082    15.7  NanJing_8
# 12  CPSNJ19  61.263220       15978    15.7  NanJing_8
# 13  CPSNJ20  46.945465       17732    15.9  NanJing_8
# 14       s1  75.625654        9157    14.9   ShangHai
# 15      s10  52.128711        9693    15.2   ShangHai
# ...

# %%
sns.displot(data=df,
            x='Total GB',
            color='#e6ab02',binwidth=2)
plt.savefig(r'D:\soil\manuscript\draft\mine\bases.svg')

# %%
fig, ax = plt.subplots()
ax=sns.boxplot(data=df, x="Site", y="Total GB",color='white')
sns.swarmplot(data=df, x="Site", y="Total GB")
#plt.savefig(r'D:\soil\compare\binning_completeness.png',dpi=300,bbox_inches='tight')
# Out:
# <AxesSubplot:xlabel='Site', ylabel='Total GB'>

# %%
sns.displot(data=df,
            x='N50 length',
            color='#7570b3',binwidth=1000)
plt.savefig(r'D:\soil\manuscript\draft\mine\N50.svg')
plt.savefig(r'D:\soil\manuscript\draft\mine\N50.png',dpi=300)

# %%
fig, ax = plt.subplots()
ax=sns.boxplot(data=df, x="Site", y="N50 length",color='white')
sns.swarmplot(data=df, x="Site", y="N50 length")
#plt.savefig(r'D:\soil\compare\binning_completeness.png',dpi=300,bbox_inches='tight')
# Out:
# <AxesSubplot:xlabel='Site', ylabel='N50 length'>

# %%
sns.displot(data=df,
            x='Mean Q',
            color='#1b9e77',binwidth=0.1)
plt.savefig(r'D:\soil\manuscript\draft\mine\quality.svg')
plt.savefig(r'D:\soil\manuscript\draft\mine\quality.png',dpi=300)

# %%
fig, ax = plt.subplots()
ax=sns.boxplot(data=df, x="Site", y="Mean Q",color='white')
sns.swarmplot(data=df, x="Site", y="Mean Q")
#plt.savefig(r'D:\soil\compare\binning_completeness.png',dpi=300,bbox_inches='tight')
# Out:
# <AxesSubplot:xlabel='Site', ylabel='Mean Q'>

# %%
import pandas as pd
df = pd.read_csv(r'D:\soil\manuscript\draft\mine\contig.csv')
df
# Out:
#      Sample  Fragments N50  Circular contigs       Site
# 0   CPSNJ01          54070               504  NanJing_8
# 1   CPSNJ02          44941               218  NanJing_8
# 2   CPSNJ03          41825               381  NanJing_8
# 3   CPSNJ04          51557               416  NanJing_8
# 4   CPSNJ08          47353               398  NanJing_8
# 5   CPSNJ09          63901               116  NanJing_8
# 6   CPSNJ10          71491               166  NanJing_8
# 7   CPSNJ11          68347               265  NanJing_8
# 8   CPSNJ13          62823               122  NanJing_8
# 9   CPSNJ14          63624               231  NanJing_8
# 10  CPSNJ15          50468               118  NanJing_8
# 11  CPSNJ16          49507                73  NanJing_8
# 12  CPSNJ19          63897               256  NanJing_8
# 13  CPSNJ20          52833               242  NanJing_8
# 14       s1          67922               231   ShangHai
# 15      s10          66799               174   ShangHai
# ...

# %%
sns.displot(data=df,
            x='Circular contigs',
            color='#a6761d',binwidth=50)
plt.savefig(r'D:\soil\manuscript\draft\mine\circular.svg')
plt.savefig(r'D:\soil\manuscript\draft\mine\circular.png',dpi=300)

# %%
fig, ax = plt.subplots()
ax=sns.boxplot(data=df, x="Site", y="Circular contigs",color='white')
sns.swarmplot(data=df, x="Site", y="Circular contigs")
#plt.savefig(r'D:\soil\compare\binning_completeness.png',dpi=300,bbox_inches='tight')
# Out:
# <AxesSubplot:xlabel='Site', ylabel='Circular contigs'>

# %%
sns.displot(data=df,
            x='Fragments N50',
            color='#66a61e',binwidth=5000)
plt.savefig(r'D:\soil\manuscript\draft\mine\contig_N50.svg')
plt.savefig(r'D:\soil\manuscript\draft\mine\contig_N50.png',dpi=300)

# %%
fig, ax = plt.subplots()
ax=sns.boxplot(data=df, x="Site", y="Fragments N50",color='white')
sns.swarmplot(data=df, x="Site", y="Fragments N50")
#plt.savefig(r'D:\soil\compare\binning_completeness.png',dpi=300,bbox_inches='tight')
# Out:
# <AxesSubplot:xlabel='Site', ylabel='Fragments N50'>

# %%
import pandas as pd
df = pd.read_csv(r'D:\soil\manuscript\draft\mine\mag.csv')
df['Medium MAGs'] = df['GUNC HQ']+df['GUNC MQ']
df
# Out:
#      Sample  All MAGs  GUNC HQ  GUNC MQ       Site  Medium MAGs
# 0        s1      1929       40      180   ShangHai          220
# 1        s2      1015       20       76   ShangHai           96
# 2        s3      1281       15      101   ShangHai          116
# 3        s4      1436       25      122   ShangHai          147
# 4        s5      1313       26       83   ShangHai          109
# 5        s6      1819       24      138   ShangHai          162
# 6        s7      1769       39      156   ShangHai          195
# 7        s8      1999       14       67   ShangHai           81
# 8        s9      1634       10       36   ShangHai           46
# 9       s10      1386        9       45   ShangHai           54
# 10      s11      1675       11       59   ShangHai           70
# 11      s12      1270        7       57   ShangHai           64
# 12      s13      1696       34      151   ShangHai          185
# 13      s14      1670        7       75   ShangHai           82
# ...

# %%
sns.displot(data=df,
            x='All MAGs',
            color='#d95f02',binwidth=100)
plt.savefig(r'D:\soil\manuscript\draft\mine\all_mag.svg')
plt.savefig(r'D:\soil\manuscript\draft\mine\all_mag.png',dpi=300)

# %%
fig, ax = plt.subplots()
ax=sns.boxplot(data=df, x="Site", y="All MAGs",color='white')
sns.swarmplot(data=df, x="Site", y="All MAGs")
#plt.savefig(r'D:\soil\compare\binning_completeness.png',dpi=300,bbox_inches='tight')
# Out:
# <AxesSubplot:xlabel='Site', ylabel='All MAGs'>

# %%
sns.displot(data=df,
            x='GUNC HQ',
            color='#66a61e',binwidth=5)
plt.savefig(r'D:\soil\manuscript\draft\mine\hq_mag.svg')
plt.savefig(r'D:\soil\manuscript\draft\mine\hq_mag.png',dpi=300)

# %%
fig, ax = plt.subplots()
ax=sns.boxplot(data=df, x="Site", y="GUNC HQ",color='white')
sns.swarmplot(data=df, x="Site", y="GUNC HQ")
#plt.savefig(r'D:\soil\compare\binning_completeness.png',dpi=300,bbox_inches='tight')
# Out:
# <AxesSubplot:xlabel='Site', ylabel='GUNC HQ'>

# %%
sns.displot(data=df,
            x='Medium MAGs',
            color='#66a61e',binwidth=20)
plt.savefig(r'D:\soil\manuscript\draft\mine\medium_mag.svg')
plt.savefig(r'D:\soil\manuscript\draft\mine\medium_mag.png',dpi=300)

# %%
fig, ax = plt.subplots()
ax=sns.boxplot(data=df, x="Site", y="Medium MAGs",color='white')
sns.swarmplot(data=df, x="Site", y="Medium MAGs")
#plt.savefig(r'D:\soil\compare\binning_completeness.png',dpi=300,bbox_inches='tight')
# Out:
# <AxesSubplot:xlabel='Site', ylabel='Medium MAGs'>

# %%
import pandas as pd
df = pd.read_csv(r'D:\soil\manuscript\draft\mine\mag.csv',index_col=0)
df['Medium MAGs'] = df['High Quality']+df['Medium Quality']
df = df.sort_values(by='Medium MAGs', ascending=False)
df = df[['High Quality','Medium Quality']]
df
# Out:
#           High Quality  Medium Quality
# Sample
# sample18            78             214
# sample20            51             182
# sample1             40             180
# sample29            49             167
# sample16            30             171
# sample15            27             169
# sample7             39             156
# CPSNJ09             38             155
# sample17            28             162
# CPSNJ14             32             156
# sample19            39             149
# sample25            23             163
# sample13            34             151
# SNJ11               31             139
# CPSNJ11             41             129
# sample22            36             133
# SNJ09               26             140
# SNJ08               28             137
# sample6             24             138
# CPSNJ10             23             136
# CPSNJ19             27             130
# SNJ19               25             127
# CPSNJ04             23             125
# ...

# %%
ax =df.plot.bar(stacked=True,color=['#e6ab02','#1b9e77'])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set(ylabel="Number of bins")
plt.xticks([])
plt.savefig(r'D:\soil\manuscript\draft\mine\bins.png',dpi=300,bbox_inches='tight')

# %%
import pandas as pd
df = pd.read_csv(r'D:\soil\manuscript\draft\mine\bins.csv')
df
# Out:
#                    Mag ID  Completeness  Contamination    GUNC Quality MIMAG  \
# 0       cpsnj01_SemiBin_0         99.97           0.22    High quality     T
# 1      cpsnj01_SemiBin_10         91.13           2.78    High quality     T
# 2     cpsnj01_SemiBin_110         50.92           1.11  Medium quality     F
# 3     cpsnj01_SemiBin_112         57.39           6.50  Medium quality     F
# 4     cpsnj01_SemiBin_115         57.02           0.00  Medium quality     F
# ...                   ...           ...            ...             ...   ...
# 7944     snj20_SemiBin_95         70.43           9.78  Medium quality     F
# 7945    snj20_SemiBin_963         65.69           9.61  Medium quality     F
# 7946     snj20_SemiBin_96         59.11           5.13  Medium quality     F
# 7947     snj20_SemiBin_97         53.23           4.62  Medium quality     F
# 7948      snj20_SemiBin_9         79.49           3.32  Medium quality     F
#
# ...

# %%
sns.jointplot(data=df, x="Completeness", y="Contamination",hue="Quality",s=1.5,hue_order=['Medium quality','High quality','HQ-MIMAG'])
plt.savefig(r'D:\soil\manuscript\draft\mine\complete_contam.png',dpi=300)
plt.savefig(r'D:\soil\manuscript\draft\mine\complete_contam.svg')

# %%
df['log(N50)'] = np.log(df['N50'])
df
# Out:
#                    Mag ID  Completeness  Contamination    GUNC Quality MIMAG  \
# 0       cpsnj01_SemiBin_0         99.97           0.22    High quality     T
# 1      cpsnj01_SemiBin_10         91.13           2.78    High quality     T
# 2     cpsnj01_SemiBin_110         50.92           1.11  Medium quality     F
# 3     cpsnj01_SemiBin_112         57.39           6.50  Medium quality     F
# 4     cpsnj01_SemiBin_115         57.02           0.00  Medium quality     F
# ...                   ...           ...            ...             ...   ...
# 7944     snj20_SemiBin_95         70.43           9.78  Medium quality     F
# 7945    snj20_SemiBin_963         65.69           9.61  Medium quality     F
# 7946     snj20_SemiBin_96         59.11           5.13  Medium quality     F
# 7947     snj20_SemiBin_97         53.23           4.62  Medium quality     F
# 7948      snj20_SemiBin_9         79.49           3.32  Medium quality     F
#
# ...

# %%
df['log(L50)'] = np.log(df['L50'])
df
# Out:
#                    Mag ID  Completeness  Contamination    GUNC Quality MIMAG  \
# 0       cpsnj01_SemiBin_0         99.97           0.22    High quality     T
# 1      cpsnj01_SemiBin_10         91.13           2.78    High quality     T
# 2     cpsnj01_SemiBin_110         50.92           1.11  Medium quality     F
# 3     cpsnj01_SemiBin_112         57.39           6.50  Medium quality     F
# 4     cpsnj01_SemiBin_115         57.02           0.00  Medium quality     F
# ...                   ...           ...            ...             ...   ...
# 7944     snj20_SemiBin_95         70.43           9.78  Medium quality     F
# 7945    snj20_SemiBin_963         65.69           9.61  Medium quality     F
# 7946     snj20_SemiBin_96         59.11           5.13  Medium quality     F
# 7947     snj20_SemiBin_97         53.23           4.62  Medium quality     F
# 7948      snj20_SemiBin_9         79.49           3.32  Medium quality     F
#
# ...

# %%
fig, ax = plt.subplots()
ax=sns.boxplot(data=df, x="Quality", y='log(N50)',color='white',
               width=.3,order=['Medium quality','High quality','HQ-MIMAG'])
sns.stripplot(data=df, x="Quality", y='log(N50)',size=1.3,order=['Medium quality','High quality','HQ-MIMAG'])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig(r'D:\soil\manuscript\draft\mine\quality_n50.png',dpi=300)
plt.savefig(r'D:\soil\manuscript\draft\mine\quality_n50.svg')

# %%
fig, ax = plt.subplots()
ax=sns.boxplot(data=df, x="Quality", y="log(L50)",color='white',
               width=.3,order=['Medium quality','High quality','HQ-MIMAG'])
sns.stripplot(data=df, x="Quality", y="log(L50)",size=1.3,order=['Medium quality','High quality','HQ-MIMAG'])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
#plt.savefig(r'D:\soil\manuscript\draft\mine\quality_l50.png',dpi=300)
#plt.savefig(r'D:\soil\manuscript\draft\mine\quality_l50.svg')

# %%
df['log(Nr contigs)'] = np.log(df['Nr contigs'])
df
# Out:
#                    Mag ID  Completeness  Contamination    GUNC Quality MIMAG  \
# 0       cpsnj01_SemiBin_0         99.97           0.22    High quality     T
# 1      cpsnj01_SemiBin_10         91.13           2.78    High quality     T
# 2     cpsnj01_SemiBin_110         50.92           1.11  Medium quality     F
# 3     cpsnj01_SemiBin_112         57.39           6.50  Medium quality     F
# 4     cpsnj01_SemiBin_115         57.02           0.00  Medium quality     F
# ...                   ...           ...            ...             ...   ...
# 7944     snj20_SemiBin_95         70.43           9.78  Medium quality     F
# 7945    snj20_SemiBin_963         65.69           9.61  Medium quality     F
# 7946     snj20_SemiBin_96         59.11           5.13  Medium quality     F
# 7947     snj20_SemiBin_97         53.23           4.62  Medium quality     F
# 7948      snj20_SemiBin_9         79.49           3.32  Medium quality     F
#
# ...

# %%
fig, ax = plt.subplots()
sns.boxplot(data=df, x="Quality", y="log(Nr contigs)",color='white',
               width=.3,order=['Medium quality','High quality','HQ-MIMAG'])
ax=sns.stripplot(data=df, x="Quality", y="log(Nr contigs)",size=1.3,order=['Medium quality','High quality','HQ-MIMAG'])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig(r'D:\soil\manuscript\draft\mine\quality_nr.png',dpi=300)
#plt.savefig(r'D:\soil\manuscript\draft\mine\quality_nr.svg')

# %%
import pandas as pd
df = pd.read_csv(r'D:\soil\manuscript\draft\mine\gtdb_fraction.csv',index_col=0)
df['Fraction'] = df['Number of annotated SGBs'] * 100 /4171
df = df.drop(['Number of annotated SGBs'],axis=1)
df
# Out:
#           Fraction
# Rank
# Domain   99.400623
# Phylum   99.304723
# Class    99.208823
# Order    98.585471
# Family   95.037161
# Genus    63.989451
# Species   0.431551

# %%
fig = plt.figure()
ax =df.plot.bar(stacked=True,color='#66a61e')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.xticks(rotation=45)
ax.set(xlabel="")
ax.set(ylabel="Fraction of SGBs (%)")
plt.savefig(r'D:\soil\manuscript\draft\mine\sgb_gtdb.png',dpi=300,bbox_inches='tight')
plt.savefig(r'D:\soil\manuscript\draft\mine\sgb_gtdb.svg',bbox_inches='tight')

# %%
import pandas as pd
df = pd.read_csv(r'D:\soil\analysis\drep_sgb.csv',index_col=2)
df = df[['Medium Quality','High Quality','HQ-MIMAG']]
df
# Out:
#                                                     Medium Quality  \
# Taxonomy
# d__Bacteria;p__Pseudomonadota;c__Alphaproteobac...              23
# d__Bacteria;p__Acidobacteriota;c__Vicinamibacte...              11
# d__Bacteria;p__Pseudomonadota;c__Alphaproteobac...              21
# d__Bacteria;p__Pseudomonadota;c__Gammaproteobac...              22
# d__Bacteria;p__Pseudomonadota;c__Gammaproteobac...              16
# d__Bacteria;p__Methylomirabilota;c__Methylomira...              15
# d__Bacteria;p__Pseudomonadota;c__Gammaproteobac...              25
# d__Bacteria;p__Methylomirabilota;c__Methylomira...              31
# d__Bacteria;p__Acidobacteriota;c__Vicinamibacte...              17
# d__Archaea;p__Thermoproteota;c__Nitrososphaeria...              20
#
#                                                     High Quality  HQ-MIMAG
# Taxonomy
# d__Bacteria;p__Pseudomonadota;c__Alphaproteobac...             0         2
# ...

# %%
ax =df.plot.barh(stacked=True,color=['#7570b3','#1b9e77','#d95f02'])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set(xlabel="Number of MAGs")
plt.savefig(r'D:\soil\manuscript\draft\mine\sgb.png',dpi=300,bbox_inches='tight')
plt.savefig(r'D:\soil\manuscript\draft\mine\sgb.svg',bbox_inches='tight')

# %%
import pandas as pd
df = pd.read_csv(r'D:\soil\manuscript\draft\mine\sample_aro_number.tsv',sep='\t')
df
# Out:
#       Sample  Number of ARO       Site
# 0    cpsnj01             12  Nanjing_8
# 1    cpsnj02             10  Nanjing_8
# 2    cpsnj03             16  Nanjing_8
# 3    cpsnj04             14  Nanjing_8
# 4    cpsnj08             18  Nanjing_8
# 5    cpsnj09             21  Nanjing_8
# 6    cpsnj10             15  Nanjing_8
# 7    cpsnj11             16  Nanjing_8
# 8    cpsnj13             18  Nanjing_8
# 9    cpsnj14             14  Nanjing_8
# 10   cpsnj15             13  Nanjing_8
# 11   cpsnj16             17  Nanjing_8
# 12   cpsnj19             20  Nanjing_8
# 13   cpsnj20             23  Nanjing_8
# 14     snj01             23  Nanjing_5
# 15     snj02             14  Nanjing_5
# 16     snj03             19  Nanjing_5
# 17     snj04             13  Nanjing_5
# 18     snj08             16  Nanjing_5
# 19     snj09             16  Nanjing_5
# 20     snj10             12  Nanjing_5
# 21     snj11             16  Nanjing_5
# 22     snj13             18  Nanjing_5
# ...

# %%
fig, ax = plt.subplots()
ax=sns.boxplot(data=df, x="Site", y="Number of ARO",color='white')
sns.swarmplot(data=df, x="Site", y="Number of ARO")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig(r'D:\soil\manuscript\draft\mine\sample_aro.png',dpi=300,bbox_inches='tight')
plt.savefig(r'D:\soil\manuscript\draft\mine\sample_aro.svg')

# %%
import pandas as pd
df = pd.read_csv(r'D:\soil\manuscript\draft\mine\ARO.csv',index_col=0)
df
# Out:
#                                                     Number of genes
# ARO
# ARO:3002958 vanY gene in vanF cluster                            38
# ARO:3003395 Mycobacterium tuberculosis rpsL mut...               39
# ARO:3005069 rsmA                                                 40
# ARO:3002891 Streptomyces rimosus otr(A)                          54
# ARO:3002948 vanH gene in vanO cluster                            67
# ARO:3002943 vanH gene in vanB cluster                            69
# ARO:3002959 vanY gene in vanG cluster                            74
# ARO:3002909 vanG                                                 77
# ARO:3007015 qacG                                                122
# ARO:3002965 vanW gene in vanG cluster                           124
# ARO:3002961 vanY gene in vanM cluster                           142
# ARO:3002956 vanY gene in vanB cluster                           381
# ARO:3003724 vanW gene in vanI cluster                           642
# ...

# %%
ax =df.plot.barh(color='#e6ab02')
ax.set(xlabel="Number of genes")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig(r'D:\soil\manuscript\draft\mine\aro_gene_number_mag.png',dpi=300,bbox_inches='tight')
plt.savefig(r'D:\soil\manuscript\draft\mine\aro_gene_number_mag.svg')

# %%
import pandas as pd
df = pd.read_csv(r'D:\soil\manuscript\draft\mine\drug_number.tsv',sep='\t',index_col=0)
df
# Out:
#                                                     Number of genes
# Drug Class
# elfamycin antibiotic                                              3
# rifamycin antibiotic                                             14
# tetracycline antibiotic; oxazolidinone antibiot...               15
# phosphonic acid antibiotic                                       25
# fluoroquinolone antibiotic; diaminopyrimidine a...               40
# aminoglycoside antibiotic                                        41
# tetracycline antibiotic                                          56
# disinfecting agents and antiseptics                             130
# glycopeptide antibiotic                                        4213
# fluoroquinolone antibiotic; tetracycline antibi...             4540

# %%
ax =df.plot.barh(color='#66a61e')
ax.set(xlabel="Number of genes")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig(r'D:\soil\manuscript\draft\mine\drug_gene_number_mag.png',dpi=300,bbox_inches='tight')
plt.savefig(r'D:\soil\manuscript\draft\mine\drug_gene_number_mag.svg')

# %%
import pandas as pd
df = pd.read_csv(r'D:\soil\manuscript\draft\mine\mechanism_number.tsv',sep='\t',index_col=0)
df
# Out:
#                                                  Number of genes
# Resistance Mechanism
# antibiotic target alteration; antibiotic efflux                2
# antibiotic target replacement                                  2
# antibiotic inactivation                                       37
# antibiotic target protection                                  77
# antibiotic target alteration                                4257
# antibiotic efflux                                           4710

# %%
ax =df.plot.barh(color='#d95f02')
ax.set(xlabel="Number of genes")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig(r'D:\soil\manuscript\draft\mine\resistance_mechanism_gene_number_mag.png',dpi=300,bbox_inches='tight')
plt.savefig(r'D:\soil\manuscript\draft\mine\resistance_mechanism_gene_number_mag.svg')

# %%
import pandas as pd
df = pd.read_csv(r'D:\soil\manuscript\draft\mine\family_number.tsv',sep='\t',index_col=0)
df
# Out:
#                                                     Number of genes
# AMR Gene Family
# elfamycin resistant EF-Tu                                         3
# helicase-like RNA polymerase protection protein                   6
# vanX; glycopeptide resistance gene cluster                        8
# rifampin monooxygenase                                            8
# Miscellaneous ABC-F subfamily ATP-binding casse...               15
# fosfomycin thiol transferase                                     25
# antibiotic-resistant rpsL                                        39
# tetracycline-resistant ribosomal protection pro...               56
# glycopeptide resistance gene cluster; Van ligase                 80
# small multidrug resistance (SMR) antibiotic eff...              130
# vanH; glycopeptide resistance gene cluster                      189
# vanY; glycopeptide resistance gene cluster                      652
# vanW; glycopeptide resistance gene cluster                      782
# ...

# %%
ax =df.plot.barh(color='#a6761d')
ax.set(xlabel="Number of genes")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig(r'D:\soil\manuscript\draft\mine\family_gene_number_mag.png',dpi=300,bbox_inches='tight')
plt.savefig(r'D:\soil\manuscript\draft\mine\family_mechanism_gene_number_mag.svg')

# %%
df = pd.read_csv(r'D:\soil\polish\evaluation\checkm_result_report.tsv',sep='\t')
df
# Out:
#             Mag ID  Completeness  Contamination      Polish
# 0        SemiBin_0         96.90           0.95        flye
# 1        SemiBin_1        100.00           1.28        flye
# 2       SemiBin_10         77.98           1.91        flye
# 3       SemiBin_11         60.89           1.79        flye
# 4      SemiBin_110         43.54           1.85        flye
# ...            ...           ...            ...         ...
# 31791   SemiBin_94         63.82           1.38  polypolish
# 31792   SemiBin_95         67.11           9.06  polypolish
# 31793   SemiBin_96         48.22           4.17  polypolish
# 31794  SemiBin_963         64.70           9.76  polypolish
# 31795   SemiBin_97         49.70           5.68  polypolish
#
# [31796 rows x 4 columns]

# %%
fig, ax = plt.subplots()
order = ['flye','medaka','polypolish','polca']
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax=sns.boxplot(data=df, x="Polish", y="Completeness",color='white',order=order)
sns.stripplot(data=df, x="Polish", y="Completeness",order=order,size=0.6)
plt.savefig(r'D:\soil\manuscript\draft\mine\polish_evaluation_completeness.png',dpi=300,bbox_inches='tight')
plt.savefig(r'D:\soil\manuscript\draft\mine\polish_evaluation_completeness.svg')

# %%
fig, ax = plt.subplots()
order = ['flye','medaka','polypolish','polca']
ax=sns.boxplot(data=df, x="Polish", y="Contamination",color='white',order=order)
sns.stripplot(data=df, x="Polish", y="Contamination",order=order,size=0.6)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig(r'D:\soil\manuscript\draft\mine\polish_evaluation_contamination.png',dpi=300,bbox_inches='tight')
plt.savefig(r'D:\soil\manuscript\draft\mine\polish_evaluation_contamination.svg')

# %%
df = pd.read_csv(r'D:\soil\manuscript\draft\mine\mapping.csv')
df
# Out:
#      mapping rate   target
# 0           72.25  contigs
# 1           60.20  contigs
# 2           65.74  contigs
# 3           65.99  contigs
# 4           59.71  contigs
# ..            ...      ...
# 111         41.24     MAGs
# 112         25.17     MAGs
# 113         37.49     MAGs
# 114         38.58     MAGs
# 115         31.70     MAGs
#
# [116 rows x 2 columns]

# %%
fig, ax = plt.subplots()
ax=sns.boxplot(data=df, x="target", y="mapping rate",color='white')
sns.swarmplot(data=df, x="target", y="mapping rate")
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.savefig(r'D:\soil\manuscript\draft\mine\mapping_rate.png',dpi=300,bbox_inches='tight')
plt.savefig(r'D:\soil\manuscript\draft\mine\mapping_rate.svg')
