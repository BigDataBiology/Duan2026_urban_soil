# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype'] = 'none'

# %%
df = pd.read_csv('../pre-calculated_data/ARG_city.csv')
df
# Out:
#         City                         Location   sample  ARG number
# 0    Nanjing  Nanjing Agricultural University  cpsnj01         545
# 1    Nanjing  Nanjing Agricultural University  cpsnj02         527
# 2    Nanjing  Nanjing Agricultural University  cpsnj03         669
# 3    Nanjing  Nanjing Agricultural University  cpsnj04         879
# 4    Nanjing  Nanjing Agricultural University    snj01         473
# 5    Nanjing  Nanjing Agricultural University    snj02         456
# 6    Nanjing  Nanjing Agricultural University    snj03         594
# 7    Nanjing  Nanjing Agricultural University    snj04         686
# 8    Nanjing            Sun Yat-sen Mausoleum  cpsnj08         638
# 9    Nanjing            Sun Yat-sen Mausoleum  cpsnj09        1075
# 10   Nanjing            Sun Yat-sen Mausoleum  cpsnj10         838
# 11   Nanjing            Sun Yat-sen Mausoleum  cpsnj11         813
# 12   Nanjing            Sun Yat-sen Mausoleum  cpsnj13         642
# ...

# %%
custom_palette = {
    'Nanjing': '#1b9e77',
    'Shanghai': '#e6ab02',
    'SMAG': '#7570b3'
}

fig, ax = plt.subplots(figsize=(4, 5))
sns.boxplot(data=df, x="City", y="ARG number", color='white', hue="City", 
             palette=custom_palette,boxprops=dict(alpha=0.5),
            showfliers=False, ax=ax, width=0.6, order=["Nanjing", "Shanghai"])

sns.stripplot(data=df, x="City", y="ARG number", hue="City", 
             palette=custom_palette, ax=ax,size=5, jitter=True, order=["Nanjing", "Shanghai"])


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_ylabel('ARGs per sample', fontsize=12)
ax.set_xlabel('')
